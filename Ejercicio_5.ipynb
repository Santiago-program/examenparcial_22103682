# %% [markdown]
# # Tipos de operaciones sobre files
# ## rawx
# 1. r = read
# 2. a = append
# 3. w = write
# 4. x = create

# %%
while True:
    with open("21535220.txt", "a") as f:
        nick = input("Ingresa tu nickname ?")
        msg = input("Escribe el mensaje ?")
        f.write("\n" + nick + "-" + msg)

# %%
ls 21535220.txt
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: F6D2-0C5E
#
#  Directorio de C:\Users\santi
#
# 16/11/2022  17:52                 0 21535220.txt
#                1 archivos              0 bytes
#                0 dirs  378.470.375.424 bytes libres

# %%
nick = input("Ingresa tu nickname ?")
# Out:
# Ingresa tu nickname ? Mike_Tyson

# %%
nick
# Out:
# 'Mike_Tyson'

# %%
msg = input("Escribe el mensaje ?")
# Out:
# Escribe el mensaje ? Hola soy Rosa Melano y Elver Galarga

# %% [markdown]
# # Posible al 100% pregunta de examen

# %%
import socket as sc

# %%
url_="www.universidadeuropea.es"

# %%
s = sc.socket()

# %%
# s.connect((host, port))

# %%
s.connect(("www.universidadeuropea.es", 45477))

# %%
sc.gethostbyname_ex(sc.gethostname())
# Out:
# ('DESKTOP-2K5AGK0', [], ['10.100.25.24'])

# %%
# !ping 10.100.25.24
# Out:
# Haciendo ping a 10.100.25.24 con 32 bytes de datos:
# Respuesta desde 10.100.25.24: bytes=32 tiempo<1m TTL=128
# Respuesta desde 10.100.25.24: bytes=32 tiempo<1m TTL=128
# Respuesta desde 10.100.25.24: bytes=32 tiempo<1m TTL=128
# Respuesta desde 10.100.25.24: bytes=32 tiempo<1m TTL=128
#
# Estad¡sticas de ping para 10.100.25.24:
#     Paquetes: enviados = 4, recibidos = 4, perdidos = 0
#     (0% perdidos),
# Tiempos aproximados de ida y vuelta en milisegundos:
#     M¡nimo = 0ms, M ximo = 0ms, Media = 0ms
